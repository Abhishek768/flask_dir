# %% [markdown]
# SCRAPING WITH BEAUTIFUL SOUP

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
class web_scraper:
    def __init__(self, url):
        self.url = url
      
    def page_scrap(self):
        scraping_data = []
        page = req.get(self.url).text
        parsed_page = bs(page, 'html.parser')
        labels = [label for label in parsed_page.find_all('tr')[0].get_text().splitlines()[1:]]
        temp = [scraping_data.append((t, [])) for t in labels]
        return self.__td_scrap(parsed_page, scraping_data)
        
        
    def __td_scrap(self, parsed_page, scraping_data):
        td_data = parsed_page.find_all('tr')
        for j in range(1, len(parsed_page.find_all('tr')[1:])):
            i = 0
            td = td_data[j].get_text().splitlines()[1:]
            if len(td) != len(td_data[0].get_text().splitlines()[1:]):
                break
            for row_data in td:
                scraping_data[i][1].append(row_data)
                i+=1
        return self.__data_csv(scraping_data)
                
    def __data_csv(self, scraping_data):
        data = {title:column for (title, column) in scraping_data}
        return pd.DataFrame(data)

# %%
url = 'https://www.mohfw.gov.in/'
df = web_scraper(url)

# %%
data = df.page_scrap()

# %%
data
# Out:
#    S. No.           Name of State / UT Total Confirmed cases*   \
# 0       1  Andaman and Nicobar Islands                      33
# 1       2               Andhra Pradesh                    2018
# 2       3            Arunachal Pradesh                       1
# 3       4                        Assam                      65
# 4       5                        Bihar                     747
# 5       6                   Chandigarh                     174
# 6       7                 Chhattisgarh                      59
# 7       8           Dadar Nagar Haveli                       1
# 8       9                        Delhi                    7233
# 9      10                          Goa                       7
# 10     11                      Gujarat                    8541
# 11     12                      Haryana                     730
# 12     13             Himachal Pradesh                      59
# 13     14            Jammu and Kashmir                     879
# 14     15                    Jharkhand                     160
# 15     16                    Karnataka                     862
# 16     17                       Kerala                     519
# 17     18                       Ladakh                      42
# 18     19               Madhya Pradesh                    3785
# 19     20                  Maharashtra                   23401
# 20     21                      Manipur                       2
# 21     22                    Meghalaya                      13
# 22     23                      Mizoram                       1
# 23     24                       Odisha                     414
# 24     25                   Puducherry                      12
# 25     26                       Punjab                    1877
# 26     27                    Rajasthan                    3988
# 27     28                   Tamil Nadu                    8002
# 28     29                    Telengana                    1275
# 29     30                      Tripura                     152
# 30     31                  Uttarakhand                      68
# 31     32                Uttar Pradesh                    3573
# 32     33                  West Bengal                    2063
#
#    Cured/Discharged/Migrated Deaths**
# 0                         33        0
# 1                        975       45
# 2                          1        0
# 3                         34        2
# 4                        377        6
# 5                         24        2
# 6                         53        0
# 7                          0        0
# 8                       2129       73
# 9                          7        0
# 10                      2780      513
# 11                       337       11
# 12                        39        2
# 13                       427       10
# 14                        78        3
# 15                       426       31
# 16                       489        4
# 17                        21        0
# 18                      1747      221
# 19                      4786      868
# 20                         2        0
# 21                        10        1
# 22                         1        0
# 23                        85        3
# 24                         6        0
# 25                       168       31
# 26                      2264      113
# 27                      2051       53
# 28                       800       30
# 29                         2        0
# 30                        46        1
# 31                      1758       80
# 32                       499      190
